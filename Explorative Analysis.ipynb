# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
sheet = pd.read_excel("RawData/ACS_12_1YR_S0201.xls", 0, skiprows=6, skip_footer=34)
sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402 entries, 0 to 401
# Data columns (total 17 columns):
# Subject                 339 non-null object
# Unnamed: 1              0 non-null float64
# Unnamed: 2              0 non-null float64
# California              305 non-null object
# Unnamed: 4              0 non-null float64
# Unnamed: 5              0 non-null float64
# Unnamed: 6              304 non-null object
# District of Columbia    305 non-null object
# Unnamed: 8              304 non-null object
# Florida                 305 non-null object
# Unnamed: 10             304 non-null object
# Maryland                305 non-null object
# Unnamed: 12             304 non-null object
# New York                305 non-null object
# Unnamed: 14             304 non-null object
# Washington              305 non-null object
# Unnamed: 16             304 non-null object
# dtypes: float64(4), object(13)

# %%
# Clean up null columns
bad_columns = ['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 5']
good_columns = [col for col in sheet.columns if col not in bad_columns]
good_columns
# Out:
# [u'Subject',
#  u'California',
#  'Unnamed: 6',
#  u'District of Columbia',
#  'Unnamed: 8',
#  u'Florida',
#  'Unnamed: 10',
#  u'Maryland',
#  'Unnamed: 12',
#  u'New York',
#  'Unnamed: 14',
#  u'Washington',
#  'Unnamed: 16']

# %%
df = sheet.ix[:, good_columns]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 402 entries, 0 to 401
# Data columns (total 13 columns):
# Subject                 339 non-null object
# California              305 non-null object
# Unnamed: 6              304 non-null object
# District of Columbia    305 non-null object
# Unnamed: 8              304 non-null object
# Florida                 305 non-null object
# Unnamed: 10             304 non-null object
# Maryland                305 non-null object
# Unnamed: 12             304 non-null object
# New York                305 non-null object
# Unnamed: 14             304 non-null object
# Washington              305 non-null object
# Unnamed: 16             304 non-null object
# dtypes: object(13)

# %%
df
# Out:
#                            Subject        California       Unnamed: 6  \
# 0                              NaN  Total population              NaN
# 1                              NaN          Estimate  Margin of Error
# 2   TOTAL NUMBER OF RACES REPORTED               NaN              NaN
# 3                 Total population        38,041,430            *****
# 4                         One race             95.6%           +/-0.1
# 5                        Two races              4.0%           +/-0.1
# 6                      Three races              0.3%           +/-0.1
# 7               Four or more races              0.0%           +/-0.1
# 8                              NaN               NaN              NaN
# 9                      SEX AND AGE               NaN              NaN
# 10                Total population        38,041,430            *****
# 11                            Male             49.7%           +/-0.1
# ...
